# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csvpath = Path("./whale_returns.csv")

whale_returns_data_df = pd.read_csv(csvpath, index_col = "Date", parse_dates=True, infer_datetime_format=True)

whale_returns_data_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %% [raw]
# whale_daily_returns_df = whale_return_data_df.pct_change()
# whale_daily_returns_df.head()

# %%
# Count nulls
whale_returns_data_df.isnull
# Out:
# <bound method DataFrame.isnull of             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Drop nulls
whale_returns_data_df.dropna(inplace=True)
whale_returns_data_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csvpath = ("./algo_returns.csv")

algo_returns_data_df = pd.read_csv(csvpath, index_col = "Date", parse_dates=True, infer_datetime_format=True)

algo_returns_data_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns_data_df.isnull
# Out:
# <bound method DataFrame.isnull of               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]>

# %%
# Drop nulls
algo_returns_data_df.dropna(inplace=True)
algo_returns_data_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csvpath = ("./sp500_history.csv")

sp500_history_data_df = pd.read_csv(csvpath, parse_dates=True, index_col = "Date", infer_datetime_format=True)

sp500_history_data_df.sort_index(ascending = True, inplace = True)

sp500_history_data_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_history_data_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history_data_df["Close"]= sp500_history_data_df["Close"].str.replace('$','').astype("float")
sp500_history_data_df.sort_index(inplace = True)
sp500_history_data_df
# Out:
# C:\Users\eleph\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93
# ...             ...
# 2019-04-16  2907.06
# 2019-04-17  2900.45
# 2019-04-18  2905.03
# 2019-04-22  2907.97
# 2019-04-23  2933.68
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history_data_df.pct_change()

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace = True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.rename(columns = {"Close":"sp500"}, inplace = True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
df_daily = pd.concat([whale_returns_data_df, algo_returns_data_df,sp500_daily_returns], axis = "columns",join = "inner")

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
df_daily.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# Plot cumulative returns
df_cum = (1+ df_daily).cumprod()
df_cum.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
df_daily.plot(kind = "box", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
df_daily_std = pd.DataFrame(df_daily.std()).rename(columns = {0:"std"})
df_daily_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# sp500                        0.008554

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500

# Determine which portfolios are riskier than the S&P 500
higher_std = df_daily_std[df_daily_std["std"] > df_daily_std.loc["sp500", "std"]]
higher_std
# Out:
#                                   std
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
df_annualized_std = df_daily_std*np.sqrt(252)
df_annualized_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# sp500                        0.135786

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation
sp500_rolling_21 = df_daily.rolling(window = 21).std()
sp500_rolling_21.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

# Display de correlation matrix
correlation_sp500 = pd.DataFrame(df_daily.corr()).loc[:,"sp500"]
correlation_sp500[correlation_sp500==correlation_sp500[correlation_sp500<1].max()]
# Out:
# Algo 2    0.858764
# Name: sp500, dtype: float64

# %%
correlation_sp500 = df_daily.corr()
correlation_sp500.style.background_gradient()
# Out:
# <style type="text/css">
# #T_319a4_row0_col0, #T_319a4_row1_col1, #T_319a4_row2_col2, #T_319a4_row3_col3, #T_319a4_row4_col4, #T_319a4_row5_col5, #T_319a4_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_319a4_row0_col1 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_319a4_row0_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_319a4_row0_col3, #T_319a4_row3_col6 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_319a4_row0_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_319a4_row0_col5 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_319a4_row0_col6 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_319a4_row1_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_319a4_row1_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_319a4_row1_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_319a4_row1_col4 {
#   background-color: #ece7f2;
# ...

# %%
df_daily.plot(kind="scatter", y = "Algo 2", x = "sp500", figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='sp500', ylabel='Algo 2'>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio

# Calculate variance of S&P 500

# Computing beta

# Plot beta trend
rolling_covariance = df_daily['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(df_daily['sp500'])
rolling_variance = df_daily['sp500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of BH')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of BH'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
df_daily.ewm(halflife = 21,adjust = False).std().plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = df_daily.mean()*252/(df_daily.std()*np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# sp500                          0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = "bar", title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# Algo 1 outperformed market and whales while algo 2 fell below market and BHI

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
AMD_history = pd.read_csv(Path("./AMD.csv"), index_col="date", parse_dates = True, infer_datetime_format= True)
AMD_history.rename(columns = {"Close":"AMD"}, inplace = True)
AMD_history.head()
# Out:
#               AMD
# date
# 2019-05-14  27.32
# 2019-05-13  26.24
# 2019-05-10  27.96
# 2019-05-09  27.21
# 2019-05-08  27.09

# %%
# Reading data from 2nd stock
MU_history = pd.read_csv(Path("./MU.csv"), index_col="date", parse_dates = True, infer_datetime_format= True)
MU_history.rename(columns = {"Close":"MU"}, inplace = True)
MU_history.head()
# Out:
#                MU
# date
# 2019-05-14  38.51
# 2019-05-13  37.38
# 2019-05-10  38.94
# 2019-05-09  39.27
# 2019-05-08  39.75

# %%
# Reading data from 3rd stock
INTC_history = pd.read_csv(Path("./INTC.csv"), index_col="date", parse_dates = True, infer_datetime_format= True)
INTC_history.rename(columns = {"Close":"INTC"}, inplace = True)
INTC_history.head()
# Out:
#              INTC
# date
# 2019-05-14  45.17
# 2019-05-13  44.76
# 2019-05-10  46.20
# 2019-05-09  46.62
# 2019-05-08  49.24

# %%
# Combine all stocks in a single DataFrame
my_stocks = pd.concat((AMD_history, MU_history, INTC_history), axis = 1, join= "inner")
my_stocks.sort_index(ascending = True, inplace = True)
my_stocks.head()
# Out:
#              AMD    MU   INTC
# date
# 2009-05-14  4.24  4.55  15.54
# 2009-05-15  4.01  4.24  15.19
# 2009-05-18  4.14  4.68  15.52
# 2009-05-19  4.39  4.85  15.65
# 2009-05-20  4.50  4.80  15.58

# %%
# Reset Date index
my_stocks.index = my_stocks.index.normalize()

# %%
# Reorganize portfolio data by having a column per symbol
my_stocks.dropna(inplace=True)

# %%
# Calculate daily returns

# Drop NAs

# Display sample data
my_portfolio = my_stocks
my_portfolio_returns = my_portfolio.pct_change()
my_portfolio_returns.dropna(inplace = True)
my_portfolio_returns.head()
# Out:
#                  AMD        MU      INTC
# date
# 2009-05-15 -0.054245 -0.068132 -0.022523
# 2009-05-18  0.032419  0.103774  0.021725
# 2009-05-19  0.060386  0.036325  0.008376
# 2009-05-20  0.025057 -0.010309 -0.004473
# 2009-05-21 -0.035556 -0.045833 -0.025674

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data
weights = [1/3, 1/3, 1/3]
my_portfolio = my_stocks.dot(weights)
my_portfolio_returns = my_portfolio.pct_change()
my_portfolio_returns.dropna(inplace = True)
my_portfolio_returns.head()
# Out:
# date
# 2009-05-15   -0.036580
# 2009-05-18    0.038396
# 2009-05-19    0.022597
# 2009-05-20   -0.000402
# 2009-05-21   -0.031350
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
portfolio_returns = pd.concat((my_portfolio_returns,df_daily), axis = 1, join = "inner")
portfolio_returns.rename(columns = {0:"my_portfolio"}, inplace = True)
portfolio_returns
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03     -0.023573                  -0.001266           -0.004981
# 2015-03-04     -0.006876                   0.002230            0.003241
# 2015-03-05     -0.006698                   0.004016            0.004076
# 2015-03-06     -0.020912                  -0.007905           -0.003574
# 2015-03-09     -0.004643                   0.000582            0.004225
# ...                  ...                        ...                 ...
# 2019-04-16      0.015706                   0.002699            0.000388
# 2019-04-17      0.014129                  -0.002897           -0.006467
# 2019-04-18      0.002864                   0.001448            0.001222
# 2019-04-22      0.006406                  -0.002586           -0.007333
# 2019-04-23     -0.006748                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
portfolio_returns.dropna(inplace=True)
portfolio_returns
# Out:
#             my_portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03     -0.023573                  -0.001266           -0.004981
# 2015-03-04     -0.006876                   0.002230            0.003241
# 2015-03-05     -0.006698                   0.004016            0.004076
# 2015-03-06     -0.020912                  -0.007905           -0.003574
# 2015-03-09     -0.004643                   0.000582            0.004225
# ...                  ...                        ...                 ...
# 2019-04-16      0.015706                   0.002699            0.000388
# 2019-04-17      0.014129                  -0.002897           -0.006467
# 2019-04-18      0.002864                   0.001448            0.001222
# 2019-04-22      0.006406                  -0.002586           -0.007333
# 2019-04-23     -0.006748                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
#portfolio_std = pd.DataFrame(portfolio_returns.std()).rename(columns = {0:"std"})
#portfolio_std

daily_std = portfolio_returns.std().sort_values(ascending=False)
daily_std

annualized_std = daily_std*np.sqrt(252)
annualized_std
# Out:
# my_portfolio                   0.299849
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# sp500                          0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
calculate_std = lambda df:df.rolling(window=21).std()

# Plot rolling standard deviation
#my_portfolio_rolling_21 = portfolio_returns[["my_portfolio"]].rolling(window = 21).std()

#ax = my_portfolio_rolling_21.plot(figsize = (20,10), title = 'my portfolio std')

#ax.legend(['rolling_21'])

portfolio_returns.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
#correlation_my_portfolio = pd.DataFrame(df_daily.corr()).loc[:,"my_portfolio"]
#correlation_my_portfolio[correlation_my_portfolio==correlation_my_portfolio[correlation_my_portfolio<1].max()]

portfolio_correlation = df_daily.corr()
display(portfolio_correlation)
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# sp500                                         0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Calculate and plot the correlation

correlation_my_portfolio = df_daily.corr()
correlation_my_portfolio.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c82d9_row0_col0, #T_c82d9_row1_col1, #T_c82d9_row2_col2, #T_c82d9_row3_col3, #T_c82d9_row4_col4, #T_c82d9_row5_col5, #T_c82d9_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c82d9_row0_col1 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_c82d9_row0_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_c82d9_row0_col3, #T_c82d9_row3_col6 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_c82d9_row0_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c82d9_row0_col5 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_c82d9_row0_col6 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_c82d9_row1_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_c82d9_row1_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_c82d9_row1_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_c82d9_row1_col4 {
#   background-color: #ece7f2;
# ...

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
rolling_covariance = portfolio_returns['my_portfolio'].rolling(window=60).cov(portfolio_returns['sp500'])
rolling_variance = portfolio_returns['sp500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of my portfolio')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of my portfolio'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
trading_days = portfolio_returns.count()
sharpe_ratios = portfolio_returns.mean()*trading_days/(portfolio_returns.std()*np.sqrt(trading_days))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = 'bar', title = "sharpe ratios")
# Out:
# <AxesSubplot:title={'center':'sharpe ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# My portfolio edges out the S&P500 and BHI in performance.
